# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# features/ csv -> dataframe
feat_edu_raw = pd.read_csv("./birth_csv/feat_edu.csv")
df_edu = pd.DataFrame(feat_edu_raw)
feat_hou_raw = pd.read_csv("./birth_csv/feat_hou.csv")
df_hou = pd.DataFrame(feat_hou_raw)
feat_mar_raw = pd.read_csv("./birth_csv/feat_mar.csv")
df_mar = pd.DataFrame(feat_mar_raw)
feat_preg_raw = pd.read_csv("./birth_csv/feat_preg.csv")
df_preg = pd.DataFrame(feat_preg_raw)
feat_sal_raw = pd.read_csv("./birth_csv/feat_sal.csv")
df_sal = pd.DataFrame(feat_sal_raw)

# target/ csv -> dataframe
target_birth_raw = pd.read_csv("./birth_csv/target_birth.csv")
df_birth = pd.DataFrame(target_birth_raw)

# 'ADD_UP'이 포함된 데이터 제거
df_birth = df_birth[~df_birth['AREA'].str.contains('ADD_UP', na=False)]

# 고유한 지역 리스트 추출
areas = df_birth['AREA'].unique()

# feature dict / target dict
features_dict = {}
target_dict = {}

# %%
# 각 지역별 feature와 target 데이터 생성
for area in areas:
    area_target = df_birth[df_birth['AREA'] == area].drop(columns='AREA').transpose()
    area_target.columns = ['TARGET']

    # 각 feature 데이터 생성
    area_feat_edu = df_edu[df_edu['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_edu.columns = ['EDU']
    
    area_feat_hou = df_hou[df_hou['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_hou.columns = ['HOU']
    
    area_feat_mar = df_mar[df_mar['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_mar.columns = ['MAR']
    
    area_feat_preg = df_preg[df_preg['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_preg.columns = ['PREG']
    
    area_feat_sal = df_sal[df_sal['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_sal.columns = ['SAL']

    # 지역별 feature 데이터 결합
    area_features = pd.concat([area_feat_edu, area_feat_hou, area_feat_mar, area_feat_preg, area_feat_sal], axis=1)

    # 'ADD_UP'이 포함된 features 데이터 제거
    area_features = area_features[~area_features.index.str.contains('ADD_UP', na=False)]

    # dictionary에 feature와 target 저장
    features_dict[area] = area_features
    target_dict[area] = area_target

# %%
# 각 지역에 대해 학습 및 평가 진행
for area in features_dict.keys():
    print(f"\n{area} 데이터에 대한 학습 시작")

    # 해당 지역의 feature와 target을 가져오기
    X_area = features_dict[area]
    y_area = target_dict[area]

    # 데이터 스케일링
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_area)

    # 다항 특성 추가 (degree=2, 예시로 2차 다항식 추가)
    poly = PolynomialFeatures(degree=2)
    X_poly = poly.fit_transform(X_scaled)

    # train_test_split 80% : 20%
    X_train, X_test, y_train, y_test = train_test_split(X_poly, y_area, test_size=0.2, random_state=42)

    # Lasso 회귀 모델 + GridSearchCV
    lasso_model = Lasso()
    param_grid = {'alpha': np.logspace(-6, 6, 13)}  # alpha 하이퍼파라미터 튜닝
    grid_search = GridSearchCV(lasso_model, param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # 최적 모델
    best_lasso_model = grid_search.best_estimator_

    # 예측
    y_train_pred = best_lasso_model.predict(X_train)
    y_test_pred = best_lasso_model.predict(X_test)

    # MSE (Mean Squared Error) for Test Data
    mse = mean_squared_error(y_test, y_test_pred)
    print(f"{area} - 평균 제곱 오차 (MSE) for Test Data: {mse}")

    # R² for Test Data
    r2_test = r2_score(y_test, y_test_pred)
    print(f"{area} - 결정 계수 (R²) for Test Data: {r2_test}")

    # MAE (Mean Absolute Error) for Test Data
    mae = mean_absolute_error(y_test, y_test_pred)
    print(f"{area} - 평균 절대 오차 (MAE) for Test Data: {mae}")

    # R² for Train Data
    r2_train = r2_score(y_train, y_train_pred)
    print(f"{area} - 결정 계수 (R²) for Train Data: {r2_train}")
    print("-" * 50)  # 구분선
# Out:
# SEOUL 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.177e+05, tolerance: 4.116e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.486e+05, tolerance: 3.581e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.177e+05, tolerance: 4.116e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.486e+05, tolerance: 3.581e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.179e+05, tolerance: 4.116e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.487e+05, tolerance: 3.581e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.194e+05, tolerance: 4.116e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.495e+05, tolerance: 3.581e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.349e+05, tolerance: 4.116e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.584e+05, tolerance: 3.581e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.852e+05, tolerance: 4.116e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.452e+05, tolerance: 3.581e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.415e+05, tolerance: 3.479e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.183e+06, tolerance: 3.521e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.085e+06, tolerance: 2.858e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.147e+06, tolerance: 4.116e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.265e+06, tolerance: 3.581e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.261e+06, tolerance: 3.479e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.645e+06, tolerance: 3.521e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.495e+06, tolerance: 2.858e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.238e+06, tolerance: 4.116e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.313e+05, tolerance: 3.581e+05
#   model = cd_fast.enet_coordinate_descent(
# SEOUL - 평균 제곱 오차 (MSE) for Test Data: 7339124.723944077
# SEOUL - 결정 계수 (R²) for Test Data: 0.986787128949341
# SEOUL - 평균 절대 오차 (MAE) for Test Data: 2611.72021771075
# SEOUL - 결정 계수 (R²) for Train Data: 0.9700775061081148
# --------------------------------------------------
#
# BUSAN 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.206e+04, tolerance: 2.210e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.859e+04, tolerance: 3.003e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.015e+05, tolerance: 2.679e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.659e+05, tolerance: 2.895e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.269e+05, tolerance: 2.210e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.615e+05, tolerance: 3.302e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.707e+04, tolerance: 3.003e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.916e+04, tolerance: 2.895e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.464e+04, tolerance: 3.302e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.846e+04, tolerance: 3.003e+04
#   model = cd_fast.enet_coordinate_descent(
# BUSAN - 평균 제곱 오차 (MSE) for Test Data: 1597921.2147361026
# BUSAN - 결정 계수 (R²) for Test Data: 0.9559157386705571
# BUSAN - 평균 절대 오차 (MAE) for Test Data: 1066.496470594942
# BUSAN - 결정 계수 (R²) for Train Data: 0.9155021416446765
# --------------------------------------------------
#
# DAEGU 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.053e+04, tolerance: 1.589e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.402e+04, tolerance: 1.879e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.054e+04, tolerance: 1.665e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.846e+04, tolerance: 1.513e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.079e+05, tolerance: 1.589e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.323e+04, tolerance: 1.218e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.861e+04, tolerance: 1.879e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.943e+04, tolerance: 1.665e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.790e+04, tolerance: 1.665e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.209e+05, tolerance: 2.096e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.209e+05, tolerance: 2.096e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.209e+05, tolerance: 2.096e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.209e+05, tolerance: 2.096e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.211e+05, tolerance: 2.096e+04
#   model = cd_fast.enet_coordinate_descent(
# DAEGU - 평균 제곱 오차 (MSE) for Test Data: 571967.7701227134
# DAEGU - 결정 계수 (R²) for Test Data: 0.9765161133701923
# DAEGU - 평균 절대 오차 (MAE) for Test Data: 557.955578234546
# DAEGU - 결정 계수 (R²) for Train Data: 0.9773677592053723
# --------------------------------------------------
#
# INCHEON 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.024e+04, tolerance: 1.859e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.197e+04, tolerance: 2.064e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.574e+04, tolerance: 1.480e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.238e+05, tolerance: 2.096e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.592e+05, tolerance: 1.859e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.804e+04, tolerance: 2.064e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.847e+04, tolerance: 1.480e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.319e+05, tolerance: 2.369e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.121e+05, tolerance: 2.096e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.868e+04, tolerance: 2.064e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.969e+04, tolerance: 1.480e+04
#   model = cd_fast.enet_coordinate_descent(
# INCHEON - 평균 제곱 오차 (MSE) for Test Data: 1009736.9115844903
# INCHEON - 결정 계수 (R²) for Test Data: 0.9644913647678828
# INCHEON - 평균 절대 오차 (MAE) for Test Data: 820.9563743932913
# INCHEON - 결정 계수 (R²) for Train Data: 0.9806889568632874
# --------------------------------------------------
#
# GWANGJU 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.008e+04, tolerance: 7.270e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.145e+04, tolerance: 6.870e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.335e+04, tolerance: 7.991e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.180e+04, tolerance: 6.966e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.055e+04, tolerance: 7.270e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.213e+04, tolerance: 6.870e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.548e+03, tolerance: 5.173e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.225e+04, tolerance: 7.991e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.329e+04, tolerance: 6.966e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.215e+04, tolerance: 6.966e+03
#   model = cd_fast.enet_coordinate_descent(
# GWANGJU - 평균 제곱 오차 (MSE) for Test Data: 571158.0893088278
# GWANGJU - 결정 계수 (R²) for Test Data: 0.9370943884634595
# GWANGJU - 평균 절대 오차 (MAE) for Test Data: 640.3918752968862
# GWANGJU - 결정 계수 (R²) for Train Data: 0.9657352794492504
# --------------------------------------------------
#
# DAEJEON 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.305e+04, tolerance: 8.244e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.259e+04, tolerance: 8.666e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.369e+04, tolerance: 9.917e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.066e+04, tolerance: 9.057e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.773e+04, tolerance: 8.244e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.893e+04, tolerance: 8.666e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.966e+04, tolerance: 7.317e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.179e+04, tolerance: 9.917e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.319e+04, tolerance: 9.057e+03
#   model = cd_fast.enet_coordinate_descent(
# DAEJEON - 평균 제곱 오차 (MSE) for Test Data: 1936800.8778804354
# DAEJEON - 결정 계수 (R²) for Test Data: 0.8241976488551648
# DAEJEON - 평균 절대 오차 (MAE) for Test Data: 1259.3730393483988
# DAEJEON - 결정 계수 (R²) for Train Data: 0.9965589047826966
# --------------------------------------------------
#
# ULSAN 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.863e+03, tolerance: 4.172e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.228e+03, tolerance: 6.574e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.574e+03, tolerance: 6.049e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+04, tolerance: 5.130e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.341e+04, tolerance: 5.691e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.749e+04, tolerance: 6.574e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.710e+04, tolerance: 6.049e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.619e+03, tolerance: 5.691e+03
#   model = cd_fast.enet_coordinate_descent(
# ULSAN - 평균 제곱 오차 (MSE) for Test Data: 2767006.3771860073
# ULSAN - 결정 계수 (R²) for Test Data: 0.6466924982414979
# ULSAN - 평균 절대 오차 (MAE) for Test Data: 1525.250011353815
# ULSAN - 결정 계수 (R²) for Train Data: 0.9999706717928403
# --------------------------------------------------
#
# SEJONG 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.677e+03, tolerance: 1.202e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.892e+03, tolerance: 1.135e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.391e+03, tolerance: 1.193e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.560e+03, tolerance: 1.200e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.812e+03, tolerance: 1.063e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.124e+03, tolerance: 1.202e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.755e+03, tolerance: 1.135e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.901e+03, tolerance: 1.193e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.401e+04, tolerance: 1.063e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e+06, tolerance: 3.246e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.280e+06, tolerance: 3.347e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e+06, tolerance: 3.246e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.280e+06, tolerance: 3.347e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e+06, tolerance: 3.246e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.280e+06, tolerance: 3.347e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.326e+06, tolerance: 3.246e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.281e+06, tolerance: 3.347e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.338e+06, tolerance: 3.246e+05
#   model = cd_fast.enet_coordinate_descent(
# SEJONG - 평균 제곱 오차 (MSE) for Test Data: 100511.32931750515
# SEJONG - 결정 계수 (R²) for Test Data: 0.9060811291657649
# SEJONG - 평균 절대 오차 (MAE) for Test Data: 281.54500160467137
# SEJONG - 결정 계수 (R²) for Train Data: 0.987105104457839
# --------------------------------------------------
#
# GYEONGGI 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.284e+06, tolerance: 3.347e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.450e+06, tolerance: 3.246e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.154e+05, tolerance: 2.524e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.321e+06, tolerance: 3.347e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.406e+06, tolerance: 3.246e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.028e+06, tolerance: 3.428e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.041e+05, tolerance: 2.524e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.840e+06, tolerance: 3.820e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.584e+06, tolerance: 3.347e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.033e+06, tolerance: 3.246e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.703e+06, tolerance: 3.428e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.929e+06, tolerance: 3.820e+05
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.866e+06, tolerance: 3.347e+05
#   model = cd_fast.enet_coordinate_descent(
# GYEONGGI - 평균 제곱 오차 (MSE) for Test Data: 11913065.883545581
# GYEONGGI - 결정 계수 (R²) for Test Data: 0.9731695728620341
# GYEONGGI - 평균 절대 오차 (MAE) for Test Data: 2624.6139591237297
# GYEONGGI - 결정 계수 (R²) for Train Data: 0.9648493881994172
# --------------------------------------------------
#
# GANGWON 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.320e+04, tolerance: 3.747e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.096e+04, tolerance: 3.014e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.044e+04, tolerance: 4.402e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.217e+04, tolerance: 3.728e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.320e+04, tolerance: 3.747e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.096e+04, tolerance: 3.014e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.044e+04, tolerance: 4.402e+03
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.217e+04, tolerance: 3.728e+03
#   model = cd_fast.enet_coordinate_descent(
# ...
#
# GYEONGBUK 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.044e+05, tolerance: 2.201e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.664e+04, tolerance: 2.664e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.266e+05, tolerance: 2.201e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.669e+04, tolerance: 2.342e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.224e+04, tolerance: 1.705e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.132e+04, tolerance: 2.664e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.723e+05, tolerance: 2.201e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.251e+05, tolerance: 2.342e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.672e+04, tolerance: 1.705e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.540e+05, tolerance: 2.664e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.200e+05, tolerance: 2.383e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.400e+04, tolerance: 4.515e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.968e+04, tolerance: 5.175e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.400e+04, tolerance: 4.515e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.968e+04, tolerance: 5.175e+04
#   model = cd_fast.enet_coordinate_descent(
# GYEONGBUK - 평균 제곱 오차 (MSE) for Test Data: 659448.9430141514
# GYEONGBUK - 결정 계수 (R²) for Test Data: 0.9797025034448464
# GYEONGBUK - 평균 절대 오차 (MAE) for Test Data: 639.055524485922
# GYEONGBUK - 결정 계수 (R²) for Train Data: 0.9808462877092923
# --------------------------------------------------
#
# GYEONGNAM 데이터에 대한 학습 시작
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.403e+04, tolerance: 4.515e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.971e+04, tolerance: 5.175e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.434e+04, tolerance: 4.515e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.996e+04, tolerance: 5.175e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.742e+04, tolerance: 4.515e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.249e+04, tolerance: 5.175e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.613e+04, tolerance: 4.515e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.373e+04, tolerance: 3.281e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.063e+05, tolerance: 5.175e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+04, tolerance: 4.572e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.326e+05, tolerance: 4.266e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.677e+05, tolerance: 4.515e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.630e+05, tolerance: 3.281e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.295e+05, tolerance: 5.175e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.550e+05, tolerance: 4.572e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.911e+05, tolerance: 4.266e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.668e+05, tolerance: 4.515e+04
#   model = cd_fast.enet_coordinate_descent(
# GYEONGNAM - 평균 제곱 오차 (MSE) for Test Data: 4363539.826969499
# GYEONGNAM - 결정 계수 (R²) for Test Data: 0.9336615006388016
# GYEONGNAM - 평균 절대 오차 (MAE) for Test Data: 1903.7614182556886
# GYEONGNAM - 결정 계수 (R²) for Train Data: 0.9581426309861728
# --------------------------------------------------
#
# JEJU 데이터에 대한 학습 시작
# JEJU - 평균 제곱 오차 (MSE) for Test Data: 173348.29883638266
# JEJU - 결정 계수 (R²) for Test Data: 0.8357836492656894
# JEJU - 평균 절대 오차 (MAE) for Test Data: 332.1500609199062
# JEJU - 결정 계수 (R²) for Train Data: 0.9446572781831615
# --------------------------------------------------
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.589e+02, tolerance: 4.250e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.342e+03, tolerance: 6.073e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.491e+03, tolerance: 6.550e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.567e+03, tolerance: 4.250e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.833e+03, tolerance: 7.817e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.776e+03, tolerance: 7.177e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.319e+03, tolerance: 6.073e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.005e+03, tolerance: 6.550e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\user\miniconda3\envs\project_ml\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.207e+03, tolerance: 7.817e+02
#   model = cd_fast.enet_coordinate_descent(
