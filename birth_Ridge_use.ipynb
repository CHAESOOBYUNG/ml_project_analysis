# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# features/ csv -> dataframe
feat_edu_raw = pd.read_csv("./birth_csv/feat_edu.csv")
df_edu = pd.DataFrame(feat_edu_raw)
feat_hou_raw = pd.read_csv("./birth_csv/feat_hou.csv")
df_hou = pd.DataFrame(feat_hou_raw)
feat_mar_raw = pd.read_csv("./birth_csv/feat_mar.csv")
df_mar = pd.DataFrame(feat_mar_raw)
feat_preg_raw = pd.read_csv("./birth_csv/feat_preg.csv")
df_preg = pd.DataFrame(feat_preg_raw)
feat_sal_raw = pd.read_csv("./birth_csv/feat_sal.csv")
df_sal = pd.DataFrame(feat_sal_raw)

# target/ csv -> dataframe
target_birth_raw = pd.read_csv("./birth_csv/target_birth.csv")
df_birth = pd.DataFrame(target_birth_raw)

# 'ADD_UP'이 포함된 데이터 제거
df_birth = df_birth[~df_birth['AREA'].str.contains('ADD_UP', na=False)]

# 고유한 지역 리스트 추출
areas = df_birth['AREA'].unique()

# feature dict / target dict
features_dict = {}
target_dict = {}

# %%
# 각 지역별 feature와 target 데이터 생성
for area in areas:
    area_target = df_birth[df_birth['AREA'] == area].drop(columns='AREA').transpose()
    area_target.columns = ['TARGET']

    # 각 feature 데이터 생성
    area_feat_edu = df_edu[df_edu['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_edu.columns = ['EDU']
    
    area_feat_hou = df_hou[df_hou['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_hou.columns = ['HOU']
    
    area_feat_mar = df_mar[df_mar['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_mar.columns = ['MAR']
    
    area_feat_preg = df_preg[df_preg['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_preg.columns = ['PREG']
    
    area_feat_sal = df_sal[df_sal['AREA'] == area].drop(columns='AREA').transpose()
    area_feat_sal.columns = ['SAL']

    # 지역별 feature 데이터 결합
    area_features = pd.concat([area_feat_edu, area_feat_hou, area_feat_mar, area_feat_preg, area_feat_sal], axis=1)

    # 'ADD_UP'이 포함된 features 데이터 제거
    area_features = area_features[~area_features.index.str.contains('ADD_UP', na=False)]

    # dictionary에 feature와 target 저장
    features_dict[area] = area_features
    target_dict[area] = area_target

# %%
# 각 지역에 대해 학습 및 평가 진행
for area in features_dict.keys():
    print(f"\n{area} 데이터에 대한 학습 시작")

    # 해당 지역의 feature와 target을 가져오기
    X_area = features_dict[area]
    y_area = target_dict[area]

    # 데이터 스케일링
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_area)

    # 다항 특성 추가 (degree=2, 예시로 2차 다항식 추가)
    poly = PolynomialFeatures(degree=2)
    X_poly = poly.fit_transform(X_scaled)

    # train_test_split 80% : 20%
    X_train, X_test, y_train, y_test = train_test_split(X_poly, y_area, test_size=0.2, random_state=42)

    # Ridge 회귀 모델 + GridSearchCV
    ridge_model = Ridge()
    param_grid = {'alpha': np.logspace(-6, 6, 13)}  # alpha 하이퍼파라미터 튜닝
    grid_search = GridSearchCV(ridge_model, param_grid, cv=5)
    grid_search.fit(X_train, y_train)

    # 최적 모델
    best_ridge_model = grid_search.best_estimator_

    # 예측
    y_train_pred = best_ridge_model.predict(X_train)
    y_test_pred = best_ridge_model.predict(X_test)

    # MSE (Mean Squared Error) for Test Data
    mse = mean_squared_error(y_test, y_test_pred)
    print(f"{area} - 평균 제곱 오차 (MSE) for Test Data: {mse}")

    # R² for Test Data
    r2_test = r2_score(y_test, y_test_pred)
    print(f"{area} - 결정 계수 (R²) for Test Data: {r2_test}")

    # MAE (Mean Absolute Error) for Test Data
    mae = mean_absolute_error(y_test, y_test_pred)
    print(f"{area} - 평균 절대 오차 (MAE) for Test Data: {mae}")

    # R² for Train Data
    r2_train = r2_score(y_train, y_train_pred)
    print(f"{area} - 결정 계수 (R²) for Train Data: {r2_train}")
    print("-" * 50)  # 구분선
# Out:
# SEOUL 데이터에 대한 학습 시작
# SEOUL - 평균 제곱 오차 (MSE) for Test Data: 5740361.519667644
# SEOUL - 결정 계수 (R²) for Test Data: 0.9896654356757173
# SEOUL - 평균 절대 오차 (MAE) for Test Data: 2249.657419688343
# SEOUL - 결정 계수 (R²) for Train Data: 0.9891238302646531
# --------------------------------------------------
#
# BUSAN 데이터에 대한 학습 시작
# BUSAN - 평균 제곱 오차 (MSE) for Test Data: 6080880.146562313
# BUSAN - 결정 계수 (R²) for Test Data: 0.8322375928037569
# BUSAN - 평균 절대 오차 (MAE) for Test Data: 2284.49933281888
# BUSAN - 결정 계수 (R²) for Train Data: 0.988433740810668
# --------------------------------------------------
#
# DAEGU 데이터에 대한 학습 시작
# DAEGU - 평균 제곱 오차 (MSE) for Test Data: 4421975.501122229
# DAEGU - 결정 계수 (R²) for Test Data: 0.8184422676021381
# DAEGU - 평균 절대 오차 (MAE) for Test Data: 1741.1449648448001
# DAEGU - 결정 계수 (R²) for Train Data: 0.9897729606748625
# --------------------------------------------------
#
# INCHEON 데이터에 대한 학습 시작
# INCHEON - 평균 제곱 오차 (MSE) for Test Data: 15145728.911767181
# INCHEON - 결정 계수 (R²) for Test Data: 0.4673818921717502
# INCHEON - 평균 절대 오차 (MAE) for Test Data: 3234.697152246378
# INCHEON - 결정 계수 (R²) for Train Data: 0.9998991460670478
# --------------------------------------------------
#
# GWANGJU 데이터에 대한 학습 시작
# GWANGJU - 평균 제곱 오차 (MSE) for Test Data: 1404315.0964904418
# GWANGJU - 결정 계수 (R²) for Test Data: 0.8453330144695514
# GWANGJU - 평균 절대 오차 (MAE) for Test Data: 1007.9568103630161
# GWANGJU - 결정 계수 (R²) for Train Data: 0.987175551933684
# --------------------------------------------------
#
# DAEJEON 데이터에 대한 학습 시작
# DAEJEON - 평균 제곱 오차 (MSE) for Test Data: 1239188.7512244338
# DAEJEON - 결정 계수 (R²) for Test Data: 0.8875195181572318
# DAEJEON - 평균 절대 오차 (MAE) for Test Data: 969.0749711640328
# DAEJEON - 결정 계수 (R²) for Train Data: 0.9918768728978872
# --------------------------------------------------
#
# ULSAN 데이터에 대한 학습 시작
# ULSAN - 평균 제곱 오차 (MSE) for Test Data: 580269.6501680228
# ULSAN - 결정 계수 (R²) for Test Data: 0.9259077889601255
# ULSAN - 평균 절대 오차 (MAE) for Test Data: 691.7159131186002
# ULSAN - 결정 계수 (R²) for Train Data: 0.9926056768325423
# --------------------------------------------------
#
# SEJONG 데이터에 대한 학습 시작
# SEJONG - 평균 제곱 오차 (MSE) for Test Data: 144533.9313225694
# SEJONG - 결정 계수 (R²) for Test Data: 0.8649459347595707
# SEJONG - 평균 절대 오차 (MAE) for Test Data: 275.6129254507422
# SEJONG - 결정 계수 (R²) for Train Data: 0.9839620420442106
# --------------------------------------------------
#
# GYEONGGI 데이터에 대한 학습 시작
# GYEONGGI - 평균 제곱 오차 (MSE) for Test Data: 41858443.655356035
# GYEONGGI - 결정 계수 (R²) for Test Data: 0.9057270451131402
# GYEONGGI - 평균 절대 오차 (MAE) for Test Data: 5817.134744043426
# GYEONGGI - 결정 계수 (R²) for Train Data: 0.9804419319764429
# --------------------------------------------------
#
# GANGWON 데이터에 대한 학습 시작
# GANGWON - 평균 제곱 오차 (MSE) for Test Data: 224315.80134129818
# GANGWON - 결정 계수 (R²) for Test Data: 0.9629649659051994
# GANGWON - 평균 절대 오차 (MAE) for Test Data: 386.5964298892702
# GANGWON - 결정 계수 (R²) for Train Data: 0.9831769448112843
# --------------------------------------------------
#
# CHUNGBUK 데이터에 대한 학습 시작
# CHUNGBUK - 평균 제곱 오차 (MSE) for Test Data: 1003240.3616495748
# CHUNGBUK - 결정 계수 (R²) for Test Data: 0.9008320458700972
# CHUNGBUK - 평균 절대 오차 (MAE) for Test Data: 984.161627230382
# CHUNGBUK - 결정 계수 (R²) for Train Data: 0.9865891444205456
# --------------------------------------------------
#
# CHUNGNAM 데이터에 대한 학습 시작
# CHUNGNAM - 평균 제곱 오차 (MSE) for Test Data: 1204632.344876174
# CHUNGNAM - 결정 계수 (R²) for Test Data: 0.9368102079315761
# CHUNGNAM - 평균 절대 오차 (MAE) for Test Data: 1079.9850333688173
# CHUNGNAM - 결정 계수 (R²) for Train Data: 0.9900160274392736
# --------------------------------------------------
#
# JEONBUK 데이터에 대한 학습 시작
# JEONBUK - 평균 제곱 오차 (MSE) for Test Data: 330524.24894727115
# JEONBUK - 결정 계수 (R²) for Test Data: 0.9804055958136814
# JEONBUK - 평균 절대 오차 (MAE) for Test Data: 502.52030041993635
# JEONBUK - 결정 계수 (R²) for Train Data: 0.9914502577402143
# --------------------------------------------------
#
# JEONNAM 데이터에 대한 학습 시작
# JEONNAM - 평균 제곱 오차 (MSE) for Test Data: 849211.7679131813
# JEONNAM - 결정 계수 (R²) for Test Data: 0.9471533569736994
# JEONNAM - 평균 절대 오차 (MAE) for Test Data: 821.1179088167778
# JEONNAM - 결정 계수 (R²) for Train Data: 0.9909981084629268
# --------------------------------------------------
#
# GYEONGBUK 데이터에 대한 학습 시작
# GYEONGBUK - 평균 제곱 오차 (MSE) for Test Data: 710094.1710378737
# GYEONGBUK - 결정 계수 (R²) for Test Data: 0.9781436695847937
# GYEONGBUK - 평균 절대 오차 (MAE) for Test Data: 628.9272298731685
# GYEONGBUK - 결정 계수 (R²) for Train Data: 0.9881860211918565
# --------------------------------------------------
#
# GYEONGNAM 데이터에 대한 학습 시작
# GYEONGNAM - 평균 제곱 오차 (MSE) for Test Data: 2506994.158248644
# GYEONGNAM - 결정 계수 (R²) for Test Data: 0.961886395687831
# GYEONGNAM - 평균 절대 오차 (MAE) for Test Data: 1210.0515119937704
# GYEONGNAM - 결정 계수 (R²) for Train Data: 0.9864427540866527
# --------------------------------------------------
#
# JEJU 데이터에 대한 학습 시작
# JEJU - 평균 제곱 오차 (MSE) for Test Data: 1156208.1728194398
# JEJU - 결정 계수 (R²) for Test Data: -0.09529939494130035
# JEJU - 평균 절대 오차 (MAE) for Test Data: 831.0327853062868
# JEJU - 결정 계수 (R²) for Train Data: 0.9991101541079417
# --------------------------------------------------
